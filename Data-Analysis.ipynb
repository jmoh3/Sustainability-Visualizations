# %%
import pandas as pd
import geopandas as gpd

# %%
df_summary = pd.read_csv('dataOriginal/summary_2016.csv', skiprows=2, nrows=51)
df_summary.to_csv('dataViz/summary_cleaned.csv')

# %%
gpd.read_file('dataOriginal/usa.shp')
# Out:
#               STATE_NAME STATE_FIPS          SUB_REGION STATE_ABBR  \
# 0                 Alaska         02             Pacific         AK
# 1             California         06             Pacific         CA
# 2                 Hawaii         15             Pacific         HI
# 3                  Idaho         16            Mountain         ID
# 4                 Nevada         32            Mountain         NV
# 5                 Oregon         41             Pacific         OR
# 6             Washington         53             Pacific         WA
# 7                Arizona         04            Mountain         AZ
# 8               Arkansas         05  West South Central         AR
# 9               Colorado         08            Mountain         CO
# 10                  Iowa         19  West North Central         IA
# 11                Kansas         20  West North Central         KS
# 12             Louisiana         22  West South Central         LA
# ...
